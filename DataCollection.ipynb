# %%
import requests
import pandas as pd

api = "https://maayanlab.cloud/Harmonizome/static/harmonizomeapi.py"
r = requests.get(api)

with open("harmonizomeapi.py", "wb") as f:
    f.write(r.content)

# %%
from harmonizomeapi import Harmonizome
from urllib.parse import quote_plus
from tqdm import tqdm

dataset_name = "DISEASES Experimental Gene-Disease Association Evidence Scores 2025"
dataset = Harmonizome.get("dataset", name=dataset_name)
#print(dataset)

rows = []

# For loop on all the diseases to get the associated genes
for gs in tqdm(dataset["geneSets"], desc="Getting genes for all the diseases"):
    disease_name = gs["name"].split("/")[0]

    url = f"https://maayanlab.cloud/Harmonizome/api/1.0/gene_set/{quote_plus(disease_name)}/{quote_plus(dataset_name)}"
    try:
        geneset = requests.get(url).json()
    except Exception as e:
        print("Err::", disease_name, e)
        continue

    if "associations" not in geneset:
        continue

    for assoc in geneset["associations"]:
        rows.append({
            "gene": assoc["gene"]["symbol"],
            "gene_href": assoc["gene"]["href"],
            "disease": geneset["attribute"]["name"],
            "disease_href": geneset["attribute"]["href"],
            "dataset": geneset["dataset"]["name"],
            "dataset_href": geneset["dataset"]["href"],
            "threshold": assoc.get("thresholdValue"),
            "score": assoc.get("standardizedValue")
    })

df = pd.DataFrame(rows)
print("Number of rows:", len(df))
df.to_csv("gene_disease_scores.csv", index=False)

unique_counts = df.nunique()
unique_counts
# Out:
# Getting genes for all the diseases: 100%|██████████| 557/557 [05:55<00:00,  1.56it/s]
# Number of rows: 171854
# gene            10636
# gene_href       10636
# disease           557
# disease_href      557
# dataset             1
# dataset_href        1
# threshold           1
# score            1202
# dtype: int64

# %%
df
# Out:
#            gene              gene_href                             disease  \
# 0        ZBTB20   /api/1.0/gene/ZBTB20            disease of mental health
# 1           HDX      /api/1.0/gene/HDX            disease of mental health
# 2        RETNLB   /api/1.0/gene/RETNLB            disease of mental health
# 3         BEND4    /api/1.0/gene/BEND4            disease of mental health
# 4          FIGN     /api/1.0/gene/FIGN            disease of mental health
# ...         ...                    ...                                 ...
# 171849    HLA-B    /api/1.0/gene/HLA-B  proliferative diabetic retinopathy
# 171850   GOLIM4   /api/1.0/gene/GOLIM4  proliferative diabetic retinopathy
# 171851    TRPM3    /api/1.0/gene/TRPM3                          DOID:14313
# 171852    MAGI1    /api/1.0/gene/MAGI1                         Ileocolitis
# 171853  GALNT13  /api/1.0/gene/GALNT13            schizoaffective disorder
#
#                                              disease_href  \
# 0             /api/1.0/attribute/disease+of+mental+health
# 1             /api/1.0/attribute/disease+of+mental+health
# 2             /api/1.0/attribute/disease+of+mental+health
# 3             /api/1.0/attribute/disease+of+mental+health
# 4             /api/1.0/attribute/disease+of+mental+health
# ...                                                   ...
# 171849  /api/1.0/attribute/proliferative+diabetic+reti...
# 171850  /api/1.0/attribute/proliferative+diabetic+reti...
# 171851                    /api/1.0/attribute/DOID%3A14313
# 171852                     /api/1.0/attribute/Ileocolitis
# 171853        /api/1.0/attribute/schizoaffective+disorder
#
#                                                   dataset  \
# 0       DISEASES Experimental Gene-Disease Association...
# 1       DISEASES Experimental Gene-Disease Association...
# 2       DISEASES Experimental Gene-Disease Association...
# 3       DISEASES Experimental Gene-Disease Association...
# 4       DISEASES Experimental Gene-Disease Association...
# ...                                                   ...
# 171849  DISEASES Experimental Gene-Disease Association...
# 171850  DISEASES Experimental Gene-Disease Association...
# 171851  DISEASES Experimental Gene-Disease Association...
# 171852  DISEASES Experimental Gene-Disease Association...
# 171853  DISEASES Experimental Gene-Disease Association...
#
#                                              dataset_href  threshold  score
# 0       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.032
# 1       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.440
# 2       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.526
# 3       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.812
# 4       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.618
# ...                                                   ...        ...    ...
# 171849  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.986
# 171850  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.530
# 171851  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.117
# 171852  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.095
# 171853  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.252
#
# [171854 rows x 8 columns]

# %%
base_url = "https://maayanlab.cloud/Harmonizome/api/1.0"

unique_genes = df["gene"].unique()

rows = []

for g in tqdm(unique_genes, desc="Getting genes info"):
    gene_url = f"{base_url}/gene/{g}"

    resp = requests.get(gene_url)
    if resp.status_code != 200:
        print("HTTP error:", resp.status_code, "on", gene_url)
        continue

    try:
        gene_info = resp.json()
    except Exception as e:
        print("JSON parsing error on:", gene_url, e)
        continue

    rows.append({
        "gene": gene_info.get("symbol"),
        "synonyms": gene_info.get("synonyms"),
        "name": gene_info.get("name"),
        "description": gene_info.get("description"),
        "ncbiEntrezGeneId": gene_info.get("ncbiEntrezGeneId"),
        "ncbiEntrezGeneUrl": gene_info.get("ncbiEntrezGeneUrl"),
        "proteins": [p.get("symbol") for p in gene_info.get("proteins", [])] if gene_info.get("proteins") else None,
        "proteins_href": [p.get("href") for p in gene_info.get("proteins", [])] if gene_info.get("proteins") else None,
        "hgncRootFamilies": [fam.get("name") for fam in gene_info.get("hgncRootFamilies", [])] if gene_info.get("hgncRootFamilies") else None,
        "hgncRootFamilies_href": [fam.get("href") for fam in gene_info.get("hgncRootFamilies", [])] if gene_info.get("hgncRootFamilies") else None,
    })

genes = pd.DataFrame(rows)
len(genes)
# Out:
# Getting genes info:  19%|█▊        | 1984/10636 [06:47<31:42,  4.55it/s]
# HTTP error: 500 on https://maayanlab.cloud/Harmonizome/api/1.0/gene/HSPA1B
# Getting genes info:  21%|██        | 2209/10636 [07:33<30:05,  4.67it/s]
# HTTP error: 500 on https://maayanlab.cloud/Harmonizome/api/1.0/gene/HSPA1A
# Getting genes info: 100%|██████████| 10636/10636 [36:12<00:00,  4.90it/s]
# 10634

# %%
unique_counts2 = genes.astype(str).nunique()
unique_counts2
# Out:
# gene                     10634
# synonyms                  8935
# name                     10634
# description               9848
# ncbiEntrezGeneId         10634
# ncbiEntrezGeneUrl        10634
# proteins                 10131
# proteins_href            10131
# hgncRootFamilies           738
# hgncRootFamilies_href      738
# dtype: int64

# %%
genes
# Out:
#           gene                                           synonyms  \
# 0       ZBTB20                 [PRIMS, DPZF, ZNF288, HOF, ODA-8S]
# 1          HDX                           [CXORF43, D030011N01RIK]
# 2       RETNLB  [RELMB, XCP2, RELM-BETA, RELMBETA, FIZZ1, FIZZ...
# 3        BEND4                                            [CCDC4]
# 4         FIGN                                                 []
# ...        ...                                                ...
# 10629    CST9L                               [CTES7B, BA218C14.1]
# 10630     CST3                                  [HEL-S-2, ARMD11]
# 10631     CST9                                           [CTES7A]
# 10632     CST4                                                 []
# 10633  JAKMIP3    [NECC2, BA140A10.5, C10ORF14, C10ORF39, JAMIP3]
#
#                                                     name  \
# 0               zinc finger and BTB domain containing 20
# 1                              highly divergent homeobox
# 2                                     resistin like beta
# 3                                BEN domain containing 4
# 4                                               fidgetin
# ...                                                  ...
# 10629                                    cystatin 9-like
# 10630                                         cystatin C
# 10631                              cystatin 9 (testatin)
# 10632                                         cystatin S
# 10633  Janus kinase and microtubule interacting prote...
#
#                                              description  ncbiEntrezGeneId  \
# 0      This gene, which was initially designated as d...             26137
# 1      Predicted to enable DNA-binding transcription ...            139324
# 2      Predicted to enable hormone activity. Involved...             84666
# 3      Predicted to enable DNA binding activity. [pro...            389206
# 4      Predicted to enable ATP hydrolysis activity an...             55137
# ...                                                  ...               ...
# 10629  The cystatin superfamily encompasses proteins ...            128821
# 10630  The cystatin superfamily encompasses proteins ...              1471
# 10631  The cystatin superfamily encompasses proteins ...            128822
# 10632  The cystatin superfamily encompasses proteins ...              1472
# 10633  Predicted to enable kinase binding activity an...            282973
#
#                              ncbiEntrezGeneUrl       proteins  \
# 0       http://www.ncbi.nlm.nih.gov/gene/26137  [ZBT20_HUMAN]
# 1      http://www.ncbi.nlm.nih.gov/gene/139324    [HDX_HUMAN]
# 2       http://www.ncbi.nlm.nih.gov/gene/84666  [RETNB_HUMAN]
# 3      http://www.ncbi.nlm.nih.gov/gene/389206  [BEND4_HUMAN]
# 4       http://www.ncbi.nlm.nih.gov/gene/55137   [FIGN_HUMAN]
# ...                                        ...            ...
# 10629  http://www.ncbi.nlm.nih.gov/gene/128821  [CST9L_HUMAN]
# 10630    http://www.ncbi.nlm.nih.gov/gene/1471   [CYTC_HUMAN]
# 10631  http://www.ncbi.nlm.nih.gov/gene/128822   [CST9_HUMAN]
# 10632    http://www.ncbi.nlm.nih.gov/gene/1472   [CYTS_HUMAN]
# 10633  http://www.ncbi.nlm.nih.gov/gene/282973  [JKIP3_HUMAN]
#
#                         proteins_href  \
# 0      [/api/1.0/protein/ZBT20_HUMAN]
# 1        [/api/1.0/protein/HDX_HUMAN]
# 2      [/api/1.0/protein/RETNB_HUMAN]
# 3      [/api/1.0/protein/BEND4_HUMAN]
# 4       [/api/1.0/protein/FIGN_HUMAN]
# ...                               ...
# 10629  [/api/1.0/protein/CST9L_HUMAN]
# 10630   [/api/1.0/protein/CYTC_HUMAN]
# 10631   [/api/1.0/protein/CST9_HUMAN]
# 10632   [/api/1.0/protein/CYTS_HUMAN]
# 10633  [/api/1.0/protein/JKIP3_HUMAN]
#
#                                         hgncRootFamilies  \
# 0      [Zinc fingers, BTB (POZ) domain containing (BT...
# 1                                           [Homeoboxes]
# 2                                                   None
# 3                         [BEN domain containing (BEND)]
# 4                                              [ATPases]
# ...                                                  ...
# 10629                                               None
# 10630                                               None
# 10631                                               None
# 10632                                               None
# 10633                                               None
#
#                                    hgncRootFamilies_href
# 0      [/api/1.0/gene_family/Zinc+fingers, /api/1.0/g...
# 1                      [/api/1.0/gene_family/Homeoboxes]
# 2                                                   None
# 3      [/api/1.0/gene_family/BEN+domain+containing+%2...
# 4                         [/api/1.0/gene_family/ATPases]
# ...                                                  ...
# 10629                                               None
# 10630                                               None
# 10631                                               None
# 10632                                               None
# 10633                                               None
#
# [10634 rows x 10 columns]

# %%
genes.to_csv("gene_info.csv", index=False)

# %%
unique_diseases = df["disease"].unique()

rows = []

for disease_name in tqdm(unique_diseases, desc="Getting diseases info"):
    url = f"https://maayanlab.cloud/Harmonizome/api/1.0/attribute/{quote_plus(disease_name)}"
    resp = requests.get(url)
    if resp.status_code != 200:
        print("HTTP error:", resp.status_code, "on", disease_name)
        continue

    try:
        attr = resp.json()
    except Exception as e:
        print("JSON parsing error on:", disease_name, e)
        continue

    gene_sets = None
    if "geneSets" in attr and isinstance(attr["geneSets"], list):
        gene_sets = [g.get("name") for g in attr["geneSets"]]

    rows.append({
        "disease": attr.get("name"),
        "nameFromNamingAuthority": attr.get("nameFromNamingAuthority"),
        "nameFromDataset": attr.get("nameFromDataset"),
        "idFromNamingAuthority": attr.get("idFromNamingAuthority"),
        "descriptionFromNamingAuthority": attr.get("descriptionFromNamingAuthority"),
        "urlFromNamingAuthority": attr.get("urlFromNamingAuthority"),
        "namingAuthority_name": attr.get("namingAuthority", {}).get("name") if attr.get("namingAuthority") else None,
        "namingAuthority_href": attr.get("namingAuthority", {}).get("href") if attr.get("namingAuthority") else None,
        "geneSets": gene_sets
    })

diseases = pd.DataFrame(rows)
print("Totale malattie arricchite:", len(diseases))
# Out:
# Getting diseases info: 100%|██████████| 557/557 [01:53<00:00,  4.90it/s]
# Totale malattie arricchite: 557

# %%
diseases
# Out:
#                                 disease             nameFromNamingAuthority  \
# 0              disease of mental health            disease of mental health
# 1                        duodenal ulcer                      duodenal ulcer
# 2                               disease                             disease
# 3                        sleep disorder                      sleep disorder
# 4          disease of anatomical entity        disease of anatomical entity
# ..                                  ...                                 ...
# 552      childhood type dermatomyositis      childhood type dermatomyositis
# 553  proliferative diabetic retinopathy  proliferative diabetic retinopathy
# 554                          DOID:14313                          DOID:14313
# 555                         Ileocolitis                         Ileocolitis
# 556            schizoaffective disorder            schizoaffective disorder
#
#                         nameFromDataset idFromNamingAuthority  \
# 0              disease of mental health              DOID_150
# 1                        duodenal ulcer             DOID_1724
# 2                               disease           EFO_0000408
# 3                        sleep disorder              DOID_535
# 4          disease of anatomical entity                DOID_7
# ..                                  ...                   ...
# 552      childhood type dermatomyositis            DOID_14203
# 553  proliferative diabetic retinopathy            DOID_13207
# 554                          DOID:14313            DOID:14313
# 555                         Ileocolitis          DOID:0060190
# 556            schizoaffective disorder             DOID_5418
#
#                         descriptionFromNamingAuthority  \
# 0    A disease that involves a psychological or beh...
# 1          Adding UMLS CUI for Curling Ulcer C0013295.
# 2    A disease is a disposition that describes stat...
# 3    A disease of mental health that involves disru...
# 4    A disease that manifests in a defined anatomic...
# ..                                                 ...
# 552
# 553
# 554
# 555
# 556  A psychotic disorder that is characterized by ...
#
#                         urlFromNamingAuthority          namingAuthority_name  \
# 0      http://purl.obolibrary.org/obo/DOID_150        Human Disease Ontology
# 1     http://purl.obolibrary.org/obo/DOID_1724        Human Disease Ontology
# 2         http://www.ebi.ac.uk/efo/EFO_0000408  Experimental Factor Ontology
# 3      http://purl.obolibrary.org/obo/DOID_535        Human Disease Ontology
# 4        http://purl.obolibrary.org/obo/DOID_7        Human Disease Ontology
# ..                                         ...                           ...
# 552  http://purl.obolibrary.org/obo/DOID_14203        Human Disease Ontology
# 553  http://purl.obolibrary.org/obo/DOID_13207        Human Disease Ontology
# 554                                                   Human Disease Ontology
# 555                                                   Human Disease Ontology
# 556   http://purl.obolibrary.org/obo/DOID_5418        Human Disease Ontology
#
#                                   namingAuthority_href  \
# 0     /api/1.0/naming_authority/Human+Disease+Ontology
# 1     /api/1.0/naming_authority/Human+Disease+Ontology
# 2    /api/1.0/naming_authority/Experimental+Factor+...
# 3     /api/1.0/naming_authority/Human+Disease+Ontology
# 4     /api/1.0/naming_authority/Human+Disease+Ontology
# ..                                                 ...
# 552   /api/1.0/naming_authority/Human+Disease+Ontology
# 553   /api/1.0/naming_authority/Human+Disease+Ontology
# 554   /api/1.0/naming_authority/Human+Disease+Ontology
# 555   /api/1.0/naming_authority/Human+Disease+Ontology
# 556   /api/1.0/naming_authority/Human+Disease+Ontology
#
#                                               geneSets
# 0    [disease of mental health/DISEASES Experimenta...
# 1    [duodenal ulcer/HPO Gene-Disease Associations,...
# 2    [Disease/HuGE Navigator Gene-Phenotype Associa...
# 3    [Sleep disorder/DISEASES Experimental Gene-Dis...
# 4    [disease of anatomical entity/DISEASES Experim...
# ..                                                 ...
# 552  [Childhood type dermatomyositis/DISEASES Text-...
# 553  [proliferative diabetic retinopathy/DISEASES T...
# 554  [DOID:14313/DISEASES Experimental Gene-Disease...
# 555  [Ileocolitis/DISEASES Text-mining Gene-Disease...
# 556  [schizoaffective disorder/DISEASES Text-mining...
#
# [557 rows x 9 columns]

# %%
unique_counts2 = diseases.astype(str).nunique()
unique_counts2
# Out:
# disease                           557
# nameFromNamingAuthority           557
# nameFromDataset                   557
# idFromNamingAuthority             556
# descriptionFromNamingAuthority    385
# urlFromNamingAuthority            521
# namingAuthority_name               10
# namingAuthority_href               10
# geneSets                          557
# dtype: int64

# %%
diseases.to_csv("disease_info.csv", index=False)

# %%
genes_renamed = genes.rename(columns={c: f"gene_{c}" for c in genes.columns if c != "gene"})
diseases_renamed = diseases.rename(columns={c: f"disease_{c}" for c in diseases.columns if c != "disease"})

final_df = (
    df.merge(genes_renamed, on="gene", how="inner")
      .merge(diseases_renamed, on="disease", how="inner")
)

# %%
final_df
# Out:
#            gene              gene_href                             disease  \
# 0        ZBTB20   /api/1.0/gene/ZBTB20            disease of mental health
# 1           HDX      /api/1.0/gene/HDX            disease of mental health
# 2        RETNLB   /api/1.0/gene/RETNLB            disease of mental health
# 3         BEND4    /api/1.0/gene/BEND4            disease of mental health
# 4          FIGN     /api/1.0/gene/FIGN            disease of mental health
# ...         ...                    ...                                 ...
# 171703    HLA-B    /api/1.0/gene/HLA-B  proliferative diabetic retinopathy
# 171704   GOLIM4   /api/1.0/gene/GOLIM4  proliferative diabetic retinopathy
# 171705    TRPM3    /api/1.0/gene/TRPM3                          DOID:14313
# 171706    MAGI1    /api/1.0/gene/MAGI1                         Ileocolitis
# 171707  GALNT13  /api/1.0/gene/GALNT13            schizoaffective disorder
#
#                                              disease_href  \
# 0             /api/1.0/attribute/disease+of+mental+health
# 1             /api/1.0/attribute/disease+of+mental+health
# 2             /api/1.0/attribute/disease+of+mental+health
# 3             /api/1.0/attribute/disease+of+mental+health
# 4             /api/1.0/attribute/disease+of+mental+health
# ...                                                   ...
# 171703  /api/1.0/attribute/proliferative+diabetic+reti...
# 171704  /api/1.0/attribute/proliferative+diabetic+reti...
# 171705                    /api/1.0/attribute/DOID%3A14313
# 171706                     /api/1.0/attribute/Ileocolitis
# 171707        /api/1.0/attribute/schizoaffective+disorder
#
#                                                   dataset  \
# 0       DISEASES Experimental Gene-Disease Association...
# 1       DISEASES Experimental Gene-Disease Association...
# 2       DISEASES Experimental Gene-Disease Association...
# 3       DISEASES Experimental Gene-Disease Association...
# 4       DISEASES Experimental Gene-Disease Association...
# ...                                                   ...
# 171703  DISEASES Experimental Gene-Disease Association...
# 171704  DISEASES Experimental Gene-Disease Association...
# 171705  DISEASES Experimental Gene-Disease Association...
# 171706  DISEASES Experimental Gene-Disease Association...
# 171707  DISEASES Experimental Gene-Disease Association...
#
#                                              dataset_href  threshold  score  \
# 0       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.032
# 1       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.440
# 2       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.526
# 3       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.812
# 4       /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.618
# ...                                                   ...        ...    ...
# 171703  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.986
# 171704  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  0.530
# 171705  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.117
# 171706  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.095
# 171707  /api/1.0/dataset/DISEASES+Experimental+Gene-Di...        1.0  1.252
#
#                                             gene_synonyms  \
# 0                      [PRIMS, DPZF, ZNF288, HOF, ODA-8S]
# 1                                [CXORF43, D030011N01RIK]
# 2       [RELMB, XCP2, RELM-BETA, RELMBETA, FIZZ1, FIZZ...
# 3                                                 [CCDC4]
# 4                                                      []
# ...                                                   ...
# 171703                          [AS, SPDA1, HLAB, B-4901]
# 171704                      [GOLPH4, GPP130, P138, GIMPC]
# 171705                             [LTRPC3, GON-2, MLSN2]
# 171706  [MAGI-1, AIP-3, AIP3, TNRC19, WWP3, BAIAP1, MA...
# 171707                                       [GALNAC-T13]
#
#                                                 gene_name  ...  \
# 0                zinc finger and BTB domain containing 20  ...
# 1                               highly divergent homeobox  ...
# 2                                      resistin like beta  ...
# 3                                 BEN domain containing 4  ...
# 4                                                fidgetin  ...
# ...                                                   ...  ...
# 171703       major histocompatibility complex, class I, B  ...
# 171704                  golgi integral membrane protein 4  ...
# 171705  transient receptor potential cation channel, s...  ...
# 171706  membrane associated guanylate kinase, WW and P...  ...
# 171707   polypeptide N-acetylgalactosaminyltransferase 13  ...
#
#                                     gene_hgncRootFamilies  \
# 0       [Zinc fingers, BTB (POZ) domain containing (BT...
# 1                                            [Homeoboxes]
# 2                                                    None
# 3                          [BEN domain containing (BEND)]
# 4                                               [ATPases]
# ...                                                   ...
# 171703  [Immunoglobulin superfamily domain containing,...
# 171704                                               None
# 171705                                     [Ion channels]
# 171706  [Membrane-associated guanylate kinases, Trinuc...
# 171707                             [Glycosyltransferases]
#
#                                gene_hgncRootFamilies_href  \
# 0       [/api/1.0/gene_family/Zinc+fingers, /api/1.0/g...
# 1                       [/api/1.0/gene_family/Homeoboxes]
# 2                                                    None
# 3       [/api/1.0/gene_family/BEN+domain+containing+%2...
# 4                          [/api/1.0/gene_family/ATPases]
# ...                                                   ...
# 171703  [/api/1.0/gene_family/Immunoglobulin+superfami...
# 171704                                               None
# 171705                [/api/1.0/gene_family/Ion+channels]
# 171706  [/api/1.0/gene_family/Membrane-associated+guan...
# 171707        [/api/1.0/gene_family/Glycosyltransferases]
#
#            disease_nameFromNamingAuthority  \
# 0                 disease of mental health
# 1                 disease of mental health
# 2                 disease of mental health
# 3                 disease of mental health
# 4                 disease of mental health
# ...                                    ...
# 171703  proliferative diabetic retinopathy
# 171704  proliferative diabetic retinopathy
# 171705                          DOID:14313
# 171706                         Ileocolitis
# 171707            schizoaffective disorder
#
#                    disease_nameFromDataset disease_idFromNamingAuthority  \
# 0                 disease of mental health                      DOID_150
# 1                 disease of mental health                      DOID_150
# 2                 disease of mental health                      DOID_150
# 3                 disease of mental health                      DOID_150
# 4                 disease of mental health                      DOID_150
# ...                                    ...                           ...
# 171703  proliferative diabetic retinopathy                    DOID_13207
# 171704  proliferative diabetic retinopathy                    DOID_13207
# 171705                          DOID:14313                    DOID:14313
# 171706                         Ileocolitis                  DOID:0060190
# 171707            schizoaffective disorder                     DOID_5418
#
#                    disease_descriptionFromNamingAuthority  \
# 0       A disease that involves a psychological or beh...
# 1       A disease that involves a psychological or beh...
# 2       A disease that involves a psychological or beh...
# 3       A disease that involves a psychological or beh...
# 4       A disease that involves a psychological or beh...
# ...                                                   ...
# 171703
# 171704
# 171705
# 171706
# 171707  A psychotic disorder that is characterized by ...
#
#                    disease_urlFromNamingAuthority  \
# 0         http://purl.obolibrary.org/obo/DOID_150
# 1         http://purl.obolibrary.org/obo/DOID_150
# 2         http://purl.obolibrary.org/obo/DOID_150
# 3         http://purl.obolibrary.org/obo/DOID_150
# 4         http://purl.obolibrary.org/obo/DOID_150
# ...                                           ...
# 171703  http://purl.obolibrary.org/obo/DOID_13207
# 171704  http://purl.obolibrary.org/obo/DOID_13207
# 171705
# 171706
# 171707   http://purl.obolibrary.org/obo/DOID_5418
#
#        disease_namingAuthority_name  \
# 0            Human Disease Ontology
# 1            Human Disease Ontology
# 2            Human Disease Ontology
# 3            Human Disease Ontology
# 4            Human Disease Ontology
# ...                             ...
# 171703       Human Disease Ontology
# 171704       Human Disease Ontology
# 171705       Human Disease Ontology
# 171706       Human Disease Ontology
# 171707       Human Disease Ontology
#
#                             disease_namingAuthority_href  \
# 0       /api/1.0/naming_authority/Human+Disease+Ontology
# 1       /api/1.0/naming_authority/Human+Disease+Ontology
# 2       /api/1.0/naming_authority/Human+Disease+Ontology
# 3       /api/1.0/naming_authority/Human+Disease+Ontology
# 4       /api/1.0/naming_authority/Human+Disease+Ontology
# ...                                                  ...
# 171703  /api/1.0/naming_authority/Human+Disease+Ontology
# 171704  /api/1.0/naming_authority/Human+Disease+Ontology
# 171705  /api/1.0/naming_authority/Human+Disease+Ontology
# 171706  /api/1.0/naming_authority/Human+Disease+Ontology
# 171707  /api/1.0/naming_authority/Human+Disease+Ontology
#
#                                          disease_geneSets
# 0       [disease of mental health/DISEASES Experimenta...
# 1       [disease of mental health/DISEASES Experimenta...
# 2       [disease of mental health/DISEASES Experimenta...
# 3       [disease of mental health/DISEASES Experimenta...
# 4       [disease of mental health/DISEASES Experimenta...
# ...                                                   ...
# 171703  [proliferative diabetic retinopathy/DISEASES T...
# 171704  [proliferative diabetic retinopathy/DISEASES T...
# 171705  [DOID:14313/DISEASES Experimental Gene-Disease...
# 171706  [Ileocolitis/DISEASES Text-mining Gene-Disease...
# 171707  [schizoaffective disorder/DISEASES Text-mining...
#
# [171708 rows x 25 columns]

# %%
final_df.to_csv("final_dataset.csv", index=False)
